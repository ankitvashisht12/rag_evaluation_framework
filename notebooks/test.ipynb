# %% [markdown]
# # Test Notebook

# %%
import logging

# Enable DEBUG level for detailed output
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)


logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("httpcore").setLevel(logging.WARNING)
logging.getLogger("openai").setLevel(logging.WARNING)
logging.getLogger("openai._base_client").setLevel(logging.WARNING)

logging.getLogger("rag_evaluation_framework.evaluation.base_eval").setLevel(logging.DEBUG)

# %%
from rag_evaluation_framework import Evaluation

# %%
from dotenv import load_dotenv
load_dotenv("./.env")
# Out:
# True

# %%
langsmith_dataset_name = "tars-sample-dataset-for-rag-eval"
kb_path = "kb_data"

# %%
evaluation = Evaluation(
    langsmith_dataset_name=langsmith_dataset_name,
    kb_data_path=kb_path,
)
# Out:
# 2026-01-16 13:24:01,455 - rag_evaluation_framework.evaluation.base_eval - DEBUG - Initialized Evaluation with dataset='tars-sample-dataset-for-rag-eval', kb_path='kb_data', query_field='question'

# %%
evaluation.run()
# Out:
# 2026-01-16 13:24:01,464 - rag_evaluation_framework.evaluation.base_eval - INFO - Starting evaluation run with k=5
# 2026-01-16 13:24:01,465 - rag_evaluation_framework.evaluation.base_eval - DEBUG - Using default chunker: RecursiveCharTextSplitter
# 2026-01-16 13:24:01,465 - rag_evaluation_framework.evaluation.base_eval - DEBUG - Using default embedder: OpenAIEmbedder
# 2026-01-16 13:24:01,465 - rag_evaluation_framework.evaluation.vector_store.chroma - DEBUG - Initializing ChromaDB in-memory client
# 2026-01-16 13:24:01,483 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-01-16 13:24:01,538 - chromadb.config - DEBUG - Starting component System
# 2026-01-16 13:24:01,539 - chromadb.config - DEBUG - Starting component Posthog
# 2026-01-16 13:24:01,621 - rag_evaluation_framework.evaluation.vector_store.chroma - DEBUG - Using collection 'default' with cosine similarity
# ...
